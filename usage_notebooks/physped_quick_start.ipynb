# %% [markdown]
# # Physics based pedestrian modeling
#
# <p align="center">
#     <a href="https://github.com/c-pouw/physics-based-pedestrian-modeling/" alt="Repository">
# 	   <img src="https://img.shields.io/badge/GitHub-181717?style=flat&logo=github&logoColor=white" /></a>
# 	<a href="https://github.com/c-pouw/physics-based-pedestrian-modeling/actions/workflows/integration-tests.yaml" alt="Integration Tests">
# 	   <img src="https://github.com/c-pouw/physics-based-pedestrian-modeling/actions/workflows/integration-tests.yaml/badge.svg" /></a>
#     <a href="https://c-pouw.github.io/physics-based-pedestrian-modeling" alt="docs">
# 	   <img src="https://github.com/c-pouw/physics-based-pedestrian-modeling/actions/workflows/docs.yml/badge.svg" /></a>
#     <a href="https://c-pouw.github.io/physics-based-pedestrian-modeling/reports/junit/report.html?sort=result">
# 	   <img src="https://c-pouw.github.io/physics-based-pedestrian-modeling/reports/junit/tests-badge.svg?dummy=8484744" alt="tests" /></a>
#     <a href="https://c-pouw.github.io/physics-based-pedestrian-modeling/reports/coverage/index.html?">
# 	   <img src="https://c-pouw.github.io/physics-based-pedestrian-modeling/reports/coverage/coverage-badge.svg?dummy=8484744" alt="coverage" /></a>
#     <a href="https://pypi.python.org/pypi/physics-based-pedestrian-modeling" alt="pypi version">
#        <img src="https://img.shields.io/pypi/v/physics-based-pedestrian-modeling.svg" /></a>
#     <a href="#">
#        <img src="https://img.shields.io/pypi/pyversions/physics-based-pedestrian-modeling" alt="PyPI - Python Version" /></a>
#     <a href="https://opensource.org/licenses/BSD-3-Clause">
#        <img src="https://img.shields.io/badge/License-BSD%203--Clause-orange.svg" alt="Licence" /></a>
#     <a href="https://github.com/psf/black">
#        <img src="https://img.shields.io/badge/code%20style-black-000000.svg" alt="Code style: black" /></a>
# </p>
#
# # Project Overview
# Python package to create physics-based pedestrian models from pedestrian trajectory measurements. This package is an implementation of the data-driven generalized pedestrian model presented in:
#
# > Pouw, C. A. S., van der Vleuten, G., Corbetta, A., & Toschi, F. (2024). Data-driven physics-based modeling of pedestrian dynamics. Phys. Rev. E 110 (6 Dec. 2024), p. 064102. DOI: [10.1103/PhysRevE.110.064102](https://doi.org/10.1103/PhysRevE.110.064102).
#
# **Abstract.** We introduce a data-driven physics-based generalized
# Langevin model that allows robust and generic modeling of pedestrian
# behavior across any environment where extensive pedestrian trajectory
# data is available. Our model effectively captures the complex
# interplay between the deterministic movements and stochastic
# fluctuations associated with walking.
#
# <h3 align="center" style="vertical-align: middle;">
# 	<a href="https://journals.aps.org/pre/accepted/ec075Ra2H081202d17c11029a2e965c33e4471521">
# 	   <img src="https://img.shields.io/badge/PRE-Manuscript-b31b1b?style=for-the-badge" alt="PRE" /></a>
# 	<a href="https://github.com/c-pouw/physics-based-pedestrian-modeling/" alt="Repository"><img src="https://img.shields.io/badge/Github-Software-%23181717?style=for-the-badge" /></a>
#     <a href="https://doi.org/10.5281/zenodo.13784588">
# 	   <img src="https://img.shields.io/badge/Zenodo-Dataset-%231682D4?style=for-the-badge" alt="Zenodo dataset"></a>
#     <a href="https://colab.research.google.com/github/c-pouw/physics-based-pedestrian-modeling/blob/master/usage_notebooks/physped_quick_start.ipynb"><img src="https://img.shields.io/badge/Google_Colab-Demonstration-%23F9AB00?style=for-the-badge"></a>
# </h3>
#
# ## Documentation
#
# * Documentation: https://c-pouw.github.io/physics-based-pedestrian-modeling.
#
# ### This notebook shows how the generalized pedestrian model can be used with the public trajectory data sets.

# %% [markdown]
# #### Installation of the physics-based-pedestrian-modeling package
# Note: In Google Colab you might need to restart the session after installing the package.

# %%
# !pip install --upgrade physics-based-pedestrian-modeling
# Out:
# Collecting physics-based-pedestrian-modeling
#   Downloading physics_based_pedestrian_modeling-0.3.8-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (from physics-based-pedestrian-modeling) (2.2.2)
# Requirement already satisfied: numpy>2.0.0 in /usr/local/lib/python3.12/dist-packages (from physics-based-pedestrian-modeling) (2.0.2)
# Requirement already satisfied: scipy<2.0.0,>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from physics-based-pedestrian-modeling) (1.16.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.2 in /usr/local/lib/python3.12/dist-packages (from physics-based-pedestrian-modeling) (4.67.1)
# Collecting sdeint<1.0.0,>=0.3.0 (from physics-based-pedestrian-modeling)
#   Downloading sdeint-0.3.0.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib<4.0.0,>=3.8.4 in /usr/local/lib/python3.12/dist-packages (from physics-based-pedestrian-modeling) (3.10.0)
# Collecting hydra-core<2.0.0,>=1.3.2 (from physics-based-pedestrian-modeling)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting hydra-colorlog<2.0.0,>=1.2.0 (from physics-based-pedestrian-modeling)
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl.metadata (949 bytes)
# Requirement already satisfied: urllib3<3.0.0,>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from physics-based-pedestrian-modeling) (2.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from physics-based-pedestrian-modeling) (2.32.4)
# Requirement already satisfied: h11>=0.15 in /usr/local/lib/python3.12/dist-packages (from physics-based-pedestrian-modeling) (0.16.0)
# Collecting pyarrow>=20.0.0 (from physics-based-pedestrian-modeling)
#   Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->physics-based-pedestrian-modeling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->physics-based-pedestrian-modeling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->physics-based-pedestrian-modeling) (2025.3)
# Collecting colorlog (from hydra-colorlog<2.0.0,>=1.2.0->physics-based-pedestrian-modeling)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core<2.0.0,>=1.3.2->physics-based-pedestrian-modeling) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core<2.0.0,>=1.3.2->physics-based-pedestrian-modeling) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from hydra-core<2.0.0,>=1.3.2->physics-based-pedestrian-modeling) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.8.4->physics-based-pedestrian-modeling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.8.4->physics-based-pedestrian-modeling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.8.4->physics-based-pedestrian-modeling) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.8.4->physics-based-pedestrian-modeling) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.8.4->physics-based-pedestrian-modeling) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.8.4->physics-based-pedestrian-modeling) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->physics-based-pedestrian-modeling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->physics-based-pedestrian-modeling) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->physics-based-pedestrian-modeling) (2025.11.12)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf<2.4,>=2.2->hydra-core<2.0.0,>=1.3.2->physics-based-pedestrian-modeling) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2->physics-based-pedestrian-modeling) (1.17.0)
# Downloading physics_based_pedestrian_modeling-0.3.8-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 6.0 MB/s eta 0:00:00
# Downloading hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.2 MB/s eta 0:00:00
# Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 19.3 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Building wheels for collected packages: sdeint
#   Building wheel for sdeint (setup.py) ... done
#   Created wheel for sdeint: filename=sdeint-0.3.0-py3-none-any.whl size=25905 sha256=58d0768dc92ed1d23d4513d0da9f2ad6e5990539650594eded4149d6295b809d
#   Stored in directory: /root/.cache/pip/wheels/2a/91/9f/502ea62c750662210ec48d250376f9eb6acc4e379b9cd04dac
# Successfully built sdeint
# Installing collected packages: sdeint, pyarrow, colorlog, hydra-core, hydra-colorlog, physics-based-pedestrian-modeling
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
# Successfully installed colorlog-6.10.1 hydra-colorlog-1.2.0 hydra-core-1.3.2 physics-based-pedestrian-modeling-0.3.8 pyarrow-22.0.0 sdeint-0.3.0

# %% [markdown]
# #### Configuration and setup
# - Read the configuration file
# - Setup logging
# - Set matplotlib plot tyle
# - Change working directory
#
# Available configuration files
# - [Narrow corridor paths](http://doi.org/10.4121/UUID:25289586-4FDA-4931-8904-D63EFE4AA0B8)
# - Intersecting paths
# - [Eindhoven station platform 3-4 paths](https://zenodo.org/records/13784588)
# - [Amsterdam Zuid station platform 1-2 paths](https://doi.org/10.4121/20683062)

# %%
import logging
from pprint import pformat

from omegaconf import OmegaConf

from physped.utils.config_utils import initialize_hydra_config, set_plot_style

# Select one of the available environments
environments = {
    'Narrow corridor paths': 'narrow_corridor',
    'Intersecting paths': 'intersecting_paths',
    'Eindhoven station platform 3-4 paths': 'eindhoven_pf34',
    'Amsterdam Zuid station platform 1-2 paths': 'asdz_pf12'
}
env_name = environments.get('Narrow corridor paths')

# Initialize configuration with Hydra
config = initialize_hydra_config(env_name)

# Setup logging
log = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO, force = True)

# Set plot style
set_plot_style(config, use_latex=False)

# %% [markdown]
# The default model parameters are set to:
# - Noise intensiy $\sigma = 0.9\, \textrm{m s}^{-3/2}$
# - Relaxation time $\tau_x = \tau_u = 0.5$ s
# - Integration timestep $\Delta t=\frac{1}{f}$

# %%
logging.info(
    "MODELING PARAMETERS: \n" +
    pformat(OmegaConf.to_container(config.params.model, resolve=True), depth=1)
    )
# Out:
# INFO:root:MODELING PARAMETERS:
# {'dt': 0.06666666666666667,
#  'minimum_fitting_threshold': 20,
#  'sigma': 0.9,
#  'slow_positions_algorithm': 'low_pass_filter',
#  'slow_velocities_algorithm': 'low_pass_filter',
#  'tauu': 0.5,
#  'taux': 0.5}

# %% [markdown]
# #### Optional: changing the model parameters
# Parameters in the config can be changed like demonstrated in the cell below

# %%
change_config_params = True
if change_config_params:
    config.params.model.sigma = 0.6
    config.params.model.taux = 0.5
    config.params.model.tauu = 0.5
    config.params.model.dt = 1/config.params.fps

# %% [markdown]
# The cell below demonstrates how the geometry of the lattice can be changed

# %%
change_lattice_size = True
if change_lattice_size:
    config.params.grid.r.list = [0, 0.5, 1, 1.5, 2, 2.5]
    config.params.grid.spatial_cell_size = 0.4

# %% [markdown]
# #### Read and preprocess the trajectories.
# - Rename the columns
# - Prune short trajectories
# - Add a trajectory index
# - Compute velocities in Cartesian coordinates
# - Convert velocities to polar coordinates
#
# Note that the trajectory data sets are read from a remote repository, as a consequence you might get an error when the remote repository is not accessible.

# %%
from physped.processing_pipelines import read_and_preprocess_data
read_and_preprocess_data(config)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:physped.utils.config_utils:
# * Environment name: narrow_corridor
#
# * Working directory
# /content
#
# * Project root
# /usr/local/lib/python3.12/dist-packages/physped
#
# * Modeling parameters:
# {'dt': 0.06666666666666667,
#  'minimum_fitting_threshold': 20,
#  'sigma': 0.6,
#  'slow_positions_algorithm': 'low_pass_filter',
#  'slow_velocities_algorithm': 'low_pass_filter',
#  'tauu': 0.5,
#  'taux': 0.5}
# INFO:physped.io.readers:Reading trajectories
# INFO:physped.io.readers:Finished reading single paths data set.
# INFO:physped.preprocessing.trajectories:Preprocess trajectories
# INFO:physped.preprocessing.trajectories:Columns renamed to ['Pid', 'time', 'xf', 'yf']
# INFO:physped.preprocessing.trajectories:Short trajectories with less than 10 observations removed.
# INFO:physped.preprocessing.trajectories:Trajectory step added.
# INFO:physped.preprocessing.trajectories:Velocities 'uf' and 'vf' added.
# INFO:physped.preprocessing.trajectories:Velocity in polar coordinates 'rf' and 'thetaf' added
# INFO:physped.io.writers:Trajectories saved as preprocessed_trajectories.csv.

# %% [markdown]
# #### Optional: Sampling initial dynamics from the trajectory measurements
# The sampled initial dynamics are later used to initiate trajectory simulations.

# %%
from physped.processing_pipelines import sample_and_save_dynamics_from_trajectories
config.params.simulation.ntrajs = 10
sample_and_save_dynamics_from_trajectories(config)
# Out:
# INFO:physped.utils.config_utils:
# * Environment name: narrow_corridor
#
# * Working directory
# /content
#
# * Project root
# /usr/local/lib/python3.12/dist-packages/physped
#
# * Modeling parameters:
# {'dt': 0.06666666666666667,
#  'minimum_fitting_threshold': 20,
#  'sigma': 0.6,
#  'slow_positions_algorithm': 'low_pass_filter',
#  'slow_velocities_algorithm': 'low_pass_filter',
#  'tauu': 0.5,
#  'taux': 0.5}
# WARNING:physped.io.readers:Trajectories read from file.
# INFO:physped.core.slow_dynamics:Compute slow dynamics
# INFO:physped.core.slow_dynamics:Slow velocity algorithm: <function low_pass_filter_all_paths at 0x799786b82700>
# INFO:physped.preprocessing.trajectories:Velocity in polar coordinates 'rs' and 'thetas' added
# INFO:physped.core.slow_dynamics:Slow position algorithm: <function low_pass_filter_all_paths at 0x799786b82700>
# INFO:physped.core.pedestrian_initializer:Sampled 10 origins from the input trajectories.

# %% [markdown]
# #### Learn the dynamics and compute the piecewise potential
# - Fit the dynamics of the measurements conditioned to the slow dynamics with Gaussian distributions

# %%
from physped.processing_pipelines import learn_potential_from_data
learn_potential_from_data(config)
# Out:
# INFO:physped.utils.config_utils:
# * Environment name: narrow_corridor
#
# * Working directory
# /content
#
# * Project root
# /usr/local/lib/python3.12/dist-packages/physped
#
# * Modeling parameters:
# {'dt': 0.06666666666666667,
#  'minimum_fitting_threshold': 20,
#  'sigma': 0.6,
#  'slow_positions_algorithm': 'low_pass_filter',
#  'slow_velocities_algorithm': 'low_pass_filter',
#  'tauu': 0.5,
#  'taux': 0.5}
# WARNING:physped.io.readers:Trajectories read from file.
# INFO:physped.core.slow_dynamics:Compute slow dynamics
# INFO:physped.core.slow_dynamics:Slow velocity algorithm: <function low_pass_filter_all_paths at 0x799786b82700>
# INFO:physped.preprocessing.trajectories:Velocity in polar coordinates 'rs' and 'thetas' added
# INFO:physped.core.slow_dynamics:Slow position algorithm: <function low_pass_filter_all_paths at 0x799786b82700>
# INFO:physped.core.parametrize_potential:Start learning the piecewise potential
# INFO:physped.core.parametrize_potential:Periodic angular conditions applied to columns ['thetaf', 'thetas']
# INFO:physped.core.parametrize_potential:Finished learning piecewise potential from trajectories.
# INFO:physped.io.writers:Piecewise potential saved as piecewise_potential_dxy0.4_r-0-5-10-15-20-25_ntheta8.pickle.

# %% [markdown]
# #### Simulate new trajectories with the model
# - Use the sampled initial dynamics
# - Use the learned potential
# - Integrate the generalized pedestrian model
#
# The number of trajectories to simulate can be changed in the configuration as shown below.

# %%
from physped.processing_pipelines import simulate_from_potential
config.params.simulation.ntrajs = 10
simulate_from_potential(config)
# Out:
# INFO:physped.utils.config_utils:
# * Environment name: narrow_corridor
#
# * Working directory
# /content
#
# * Project root
# /usr/local/lib/python3.12/dist-packages/physped
#
# * Modeling parameters:
# {'dt': 0.06666666666666667,
#  'minimum_fitting_threshold': 20,
#  'sigma': 0.6,
#  'slow_positions_algorithm': 'low_pass_filter',
#  'slow_velocities_algorithm': 'low_pass_filter',
#  'tauu': 0.5,
#  'taux': 0.5}
# INFO:physped.core.pedestrian_simulator:Simulate trajectories using the piecewise potential
# INFO:physped.core.pedestrian_simulator:Pid 0 piece 0: Reverting 7 frames -> t = 0.33.
# INFO:physped.core.pedestrian_simulator:Pid 0 piece 1: Reverting 7 frames -> t = 0.40.
# INFO:physped.core.langevin_model:Pid 0: left the grid at t = 2.27 s
# INFO:physped.core.pedestrian_simulator:Pid 0 piece 2: Reverting 7 frames -> t = 1.80.
# INFO:physped.core.langevin_model:Pid 0: left the grid at t = 2.20 s
# WARNING:physped.core.pedestrian_simulator:Last trajectory piece has only 6 frames. Not reverting.
# INFO:physped.core.langevin_model:Pid 1: left the grid at t = 2.47 s
# INFO:physped.core.pedestrian_simulator:Pid 1 piece 0: Reverting 7 frames -> t = 2.00.
# INFO:physped.core.langevin_model:Pid 1: left the grid at t = 2.67 s
# INFO:physped.core.pedestrian_simulator:Pid 1 piece 1: Reverting 7 frames -> t = 2.20.
# INFO:physped.core.langevin_model:Pid 1: left the grid at t = 2.53 s
# WARNING:physped.core.pedestrian_simulator:Last trajectory piece has only 5 frames. Not reverting.
# INFO:physped.core.langevin_model:Pid 2: left the grid at t = 2.40 s
# INFO:physped.core.pedestrian_simulator:Pid 2 piece 0: Reverting 7 frames -> t = 1.93.
# INFO:physped.core.langevin_model:Pid 2: left the grid at t = 2.27 s
# WARNING:physped.core.pedestrian_simulator:Last trajectory piece has only 5 frames. Not reverting.
# INFO:physped.core.langevin_model:Pid 3: left the grid at t = 2.07 s
# INFO:physped.core.pedestrian_simulator:Pid 3 piece 0: Reverting 7 frames -> t = 1.60.
# INFO:physped.core.langevin_model:Pid 3: left the grid at t = 2.07 s
# INFO:physped.core.pedestrian_simulator:Pid 3 piece 1: Reverting 7 frames -> t = 1.60.
# INFO:physped.core.langevin_model:Pid 3: left the grid at t = 2.07 s
# INFO:physped.core.pedestrian_simulator:Pid 3 piece 2: Reverting 7 frames -> t = 1.60.
# INFO:physped.core.langevin_model:Pid 3: left the grid at t = 2.07 s
# WARNING:physped.core.pedestrian_simulator:Simulation already restarted 2 times. Not reverting.
# INFO:physped.core.langevin_model:Pid 4: left the grid at t = 1.73 s
# INFO:physped.core.pedestrian_simulator:Pid 4 piece 0: Reverting 7 frames -> t = 1.27.
# INFO:physped.core.langevin_model:Pid 4: left the grid at t = 1.67 s
# WARNING:physped.core.pedestrian_simulator:Last trajectory piece has only 6 frames. Not reverting.
# INFO:physped.core.langevin_model:Pid 5: left the grid at t = 1.40 s
# INFO:physped.core.pedestrian_simulator:Pid 5 piece 0: Reverting 7 frames -> t = 0.93.
# INFO:physped.core.langevin_model:Pid 5: left the grid at t = 1.47 s
# INFO:physped.core.pedestrian_simulator:Pid 5 piece 1: Reverting 7 frames -> t = 1.00.
# INFO:physped.core.langevin_model:Pid 5: left the grid at t = 1.47 s
# INFO:physped.core.pedestrian_simulator:Pid 5 piece 2: Reverting 7 frames -> t = 1.00.
# INFO:physped.core.langevin_model:Pid 5: left the grid at t = 1.53 s
# WARNING:physped.core.pedestrian_simulator:Simulation already restarted 2 times. Not reverting.
# INFO:physped.core.pedestrian_simulator:Pid 6 piece 0: Reverting 7 frames -> t = 1.73.
# INFO:physped.core.pedestrian_simulator:Pid 6 piece 1: Reverting 7 frames -> t = 1.73.
# INFO:physped.core.pedestrian_simulator:Pid 6 piece 2: Reverting 7 frames -> t = 1.73.
# INFO:physped.core.langevin_model:Pid 6: left the grid at t = 2.13 s
# WARNING:physped.core.pedestrian_simulator:Last trajectory piece has only 6 frames. Not reverting.
# INFO:physped.core.langevin_model:Pid 7: left the grid at t = 1.67 s
# INFO:physped.core.pedestrian_simulator:Pid 7 piece 0: Reverting 7 frames -> t = 1.20.
# INFO:physped.core.langevin_model:Pid 7: left the grid at t = 1.67 s
# INFO:physped.core.pedestrian_simulator:Pid 7 piece 1: Reverting 7 frames -> t = 1.20.
# INFO:physped.core.langevin_model:Pid 7: left the grid at t = 1.60 s
# WARNING:physped.core.pedestrian_simulator:Last trajectory piece has only 6 frames. Not reverting.
# INFO:physped.core.langevin_model:Pid 8: left the grid at t = 2.00 s
# INFO:physped.core.pedestrian_simulator:Pid 8 piece 0: Reverting 7 frames -> t = 1.53.
# INFO:physped.core.langevin_model:Pid 8: left the grid at t = 2.13 s
# INFO:physped.core.pedestrian_simulator:Pid 8 piece 1: Reverting 7 frames -> t = 1.67.
# INFO:physped.core.langevin_model:Pid 8: left the grid at t = 2.20 s
# INFO:physped.core.pedestrian_simulator:Pid 8 piece 2: Reverting 7 frames -> t = 1.73.
# INFO:physped.core.langevin_model:Pid 8: left the grid at t = 2.27 s
# WARNING:physped.core.pedestrian_simulator:Simulation already restarted 2 times. Not reverting.
# INFO:physped.core.langevin_model:Pid 9: left the grid at t = 1.53 s
# INFO:physped.core.pedestrian_simulator:Pid 9 piece 0: Reverting 7 frames -> t = 1.07.
# INFO:physped.core.langevin_model:Pid 9: left the grid at t = 1.60 s
# INFO:physped.core.pedestrian_simulator:Pid 9 piece 1: Reverting 7 frames -> t = 1.13.
# INFO:physped.core.langevin_model:Pid 9: left the grid at t = 1.53 s
# WARNING:physped.core.pedestrian_simulator:Last trajectory piece has only 6 frames. Not reverting.
# Simulating trajectories: 100%|██████████| 10/10 [00:11<00:00,  1.13s/trajs]
# INFO:physped.io.writers:Trajectories saved as simulated_trajectories_sigma0.6.csv.

# %% [markdown]
# #### Plot the figures

# %%
from physped.processing_pipelines import plot_figures
plot_figures(config)
# Out:
# INFO:physped.utils.config_utils:
# * Environment name: narrow_corridor
#
# * Working directory
# /content
#
# * Project root
# /usr/local/lib/python3.12/dist-packages/physped
#
# * Modeling parameters:
# {'dt': 0.06666666666666667,
#  'minimum_fitting_threshold': 20,
#  'sigma': 0.6,
#  'slow_positions_algorithm': 'low_pass_filter',
#  'slow_velocities_algorithm': 'low_pass_filter',
#  'tauu': 0.5,
#  'taux': 0.5}
# WARNING:physped.io.readers:Trajectories read from file.
# INFO:physped.core.slow_dynamics:Compute slow dynamics
# INFO:physped.core.slow_dynamics:Slow velocity algorithm: <function low_pass_filter_all_paths at 0x799786b82700>
# INFO:physped.preprocessing.trajectories:Velocity in polar coordinates 'rs' and 'thetas' added
# INFO:physped.core.slow_dynamics:Slow position algorithm: <function low_pass_filter_all_paths at 0x799786b82700>
# WARNING:physped.io.readers:Trajectories read from file.
# INFO:physped.processing_pipelines:Plot preprocessed trajectories.
# INFO:physped.processing_pipelines:Plot simulated trajectories
# INFO:physped.processing_pipelines:Plot probability distribution comparison.
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:physped.core.lattice_selection:The selected range is valid.
# INFO:physped.core.lattice_selection:The selected range is located within the grid.
# INFO:physped.processing_pipelines:Plot the configuration of the grid.
# INFO:physped.processing_pipelines:Plot potential at selection.
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
# INFO:matplotlib.mathtext:Substituting symbol P from STIXGeneral
